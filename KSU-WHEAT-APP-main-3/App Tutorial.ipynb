# %% [markdown]
# # <center>  KSU WHEAT LABELS GEN & DATA UPLOADING APPS </center>
#  ### <center> Deployment: **Nicolas Giordano** <center>
#  ##### <center> Guidance and contributions: **Andres Patrignani, PhD** <center>
#
# Welcome, Bem-vindo, Bienvenido to **KSU WHEAT LABELS GEN & DATA UPLOADING APPS**!!
#
# This apps were deployed as part of the semester projet for AGRON 845 at Kansas State University.
#
# If you are reading this tutorial it is because probably is your first time in running the apps or you found some issues!. Any issues, debugs can be reported to Nicolas Giordano at ngiordano@ksu.edu.
#
# A video tutorial on [how to use KSU WHEAT App](https://youtu.be/oZspneaWIgI) is uploaded in YouTube

# %% [markdown]
#  ## Libraries instalation
#
# If this is your first time running the app in your computer you should install the following libraries below

# %%
# !pip install streamlit
# !pip install pandas
# !pip install qrcode
# !pip install reportlab
# !pip install PyPDF2
# !pip install numpy
# !pip install streamlit_option_menu
# !pip install streamlit_multipage
# !pip install matplotlib
# Out:
# Collecting streamlit
#   Downloading streamlit-1.13.0-py2.py3-none-any.whl (9.2 MB)
# Requirement already satisfied: click>=7.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging>=14.1 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit) (21.3)
# Collecting pyarrow>=4.0
#   Downloading pyarrow-9.0.0-cp39-cp39-win_amd64.whl (19.6 MB)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
# Requirement already satisfied: watchdog in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Collecting rich>=10.11.0
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
# Requirement already satisfied: tornado>=5.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit) (6.1)
# Collecting altair>=3.2.0
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit) (9.0.1)
# Requirement already satisfied: numpy in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit) (1.21.5)
# Requirement already satisfied: toml in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Collecting blinker>=1.0.0
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.0b3-py2.py3-none-any.whl (4.7 MB)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit) (4.11.3)
# Requirement already satisfied: protobuf!=3.20.2,<4,>=3.12 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit) (3.19.1)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit) (1.4.2)
# Requirement already satisfied: python-dateutil in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
# Requirement already satisfied: cachetools>=4.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: requests>=2.4 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit) (2.27.1)
# Collecting tzlocal>=1.1
#   Downloading tzlocal-4.2-py3-none-any.whl (19 kB)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit) (4.1.1)
# Requirement already satisfied: jinja2 in c:\users\jorgeromero\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: toolz in c:\users\jorgeromero\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.11.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (4.4.0)
# Requirement already satisfied: entrypoints in c:\users\jorgeromero\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: colorama in c:\users\jorgeromero\anaconda3\lib\site-packages (from click>=7.0->streamlit) (0.4.4)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\jorgeromero\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.7.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (21.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\jorgeromero\anaconda3\lib\site-packages (from packaging>=14.1->streamlit) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jorgeromero\anaconda3\lib\site-packages (from pandas>=0.21.0->streamlit) (2021.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jorgeromero\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\jorgeromero\anaconda3\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jorgeromero\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jorgeromero\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jorgeromero\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2.0.4)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit) (2.11.2)
# Collecting tzdata
#   Downloading tzdata-2022.4-py2.py3-none-any.whl (336 kB)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py): started
#   Building wheel for validators (setup.py): finished with status 'done'
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19582 sha256=e73b4becff986bcb5d56e2cb103551d97038438f133f3a7416bf8ef7d48e7923
#   Stored in directory: c:\users\jorgeromero\appdata\local\pip\cache\wheels\2d\f0\a8\1094fca7a7e5d0d12ff56e0c64675d72aa5cc81a5fc200e849
# Successfully built validators
# Installing collected packages: tzdata, smmap, pytz-deprecation-shim, gitdb, commonmark, validators, tzlocal, semver, rich, pympler, pydeck, pyarrow, gitpython, blinker, altair, streamlit
# Successfully installed altair-4.2.0 blinker-1.5 commonmark-0.9.1 gitdb-4.0.9 gitpython-3.1.29 pyarrow-9.0.0 pydeck-0.8.0b3 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 rich-12.6.0 semver-2.13.0 smmap-5.0.0 streamlit-1.13.0 tzdata-2022.4 tzlocal-4.2 validators-0.20.0
# Requirement already satisfied: pandas in c:\users\jorgeromero\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jorgeromero\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jorgeromero\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\jorgeromero\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\jorgeromero\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting qrcode
#   Downloading qrcode-7.3.1.tar.gz (43 kB)
# Requirement already satisfied: colorama in c:\users\jorgeromero\anaconda3\lib\site-packages (from qrcode) (0.4.4)
# Building wheels for collected packages: qrcode
#   Building wheel for qrcode (setup.py): started
#   Building wheel for qrcode (setup.py): finished with status 'done'
#   Created wheel for qrcode: filename=qrcode-7.3.1-py3-none-any.whl size=40401 sha256=72ab791bfbcd72bfe21e95beea8fb4924bc308da50f74dc7f741c2278e3c1f39
#   Stored in directory: c:\users\jorgeromero\appdata\local\pip\cache\wheels\93\54\16\55cec87f8d902ed84b94ab8fdb7e89ae1158c06e130bc83b03
# Successfully built qrcode
# Installing collected packages: qrcode
# Successfully installed qrcode-7.3.1
# Collecting reportlab
#   Downloading reportlab-3.6.11-cp39-cp39-win_amd64.whl (2.3 MB)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from reportlab) (9.0.1)
# Installing collected packages: reportlab
# Successfully installed reportlab-3.6.11
# Collecting PyPDF2
#   Downloading PyPDF2-2.11.1-py3-none-any.whl (220 kB)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from PyPDF2) (4.1.1)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-2.11.1
# Requirement already satisfied: numpy in c:\users\jorgeromero\anaconda3\lib\site-packages (1.21.5)
# Collecting streamlit_option_menu
#   Downloading streamlit_option_menu-0.3.2-py3-none-any.whl (712 kB)
# Requirement already satisfied: streamlit>=0.63 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit_option_menu) (1.13.0)
# Requirement already satisfied: python-dateutil in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (2.8.2)
# Requirement already satisfied: validators>=0.2 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (0.20.0)
# Requirement already satisfied: altair>=3.2.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (4.2.0)
# Requirement already satisfied: pympler>=0.9 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (1.0.1)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (4.1.1)
# Requirement already satisfied: requests>=2.4 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (2.27.1)
# Requirement already satisfied: packaging>=14.1 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (21.3)
# Requirement already satisfied: click>=7.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (8.0.4)
# Requirement already satisfied: protobuf!=3.20.2,<4,>=3.12 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (3.19.1)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (1.4.2)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (9.0.0)
# Requirement already satisfied: tzlocal>=1.1 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (4.2)
# Requirement already satisfied: cachetools>=4.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (4.2.2)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (3.1.29)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (4.11.3)
# Requirement already satisfied: semver in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (2.13.0)
# Requirement already satisfied: watchdog in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (2.1.6)
# Requirement already satisfied: rich>=10.11.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (12.6.0)
# Requirement already satisfied: tornado>=5.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (6.1)
# Requirement already satisfied: toml in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (0.10.2)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (0.8.0b3)
# Requirement already satisfied: numpy in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (1.21.5)
# Requirement already satisfied: blinker>=1.0.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (1.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from streamlit>=0.63->streamlit_option_menu) (9.0.1)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit_option_menu) (4.4.0)
# Requirement already satisfied: jinja2 in c:\users\jorgeromero\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit_option_menu) (2.11.3)
# Requirement already satisfied: entrypoints in c:\users\jorgeromero\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit_option_menu) (0.4)
# Requirement already satisfied: toolz in c:\users\jorgeromero\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit_option_menu) (0.11.2)
# Requirement already satisfied: colorama in c:\users\jorgeromero\anaconda3\lib\site-packages (from click>=7.0->streamlit>=0.63->streamlit_option_menu) (0.4.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\jorgeromero\anaconda3\lib\site-packages (from gitpython!=3.1.19->streamlit>=0.63->streamlit_option_menu) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\jorgeromero\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit>=0.63->streamlit_option_menu) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\jorgeromero\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit>=0.63->streamlit_option_menu) (3.7.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.63->streamlit_option_menu) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.63->streamlit_option_menu) (0.18.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\jorgeromero\anaconda3\lib\site-packages (from packaging>=14.1->streamlit>=0.63->streamlit_option_menu) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jorgeromero\anaconda3\lib\site-packages (from pandas>=0.21.0->streamlit>=0.63->streamlit_option_menu) (2021.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jorgeromero\anaconda3\lib\site-packages (from jinja2->altair>=3.2.0->streamlit>=0.63->streamlit_option_menu) (2.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\jorgeromero\anaconda3\lib\site-packages (from python-dateutil->streamlit>=0.63->streamlit_option_menu) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jorgeromero\anaconda3\lib\site-packages (from requests>=2.4->streamlit>=0.63->streamlit_option_menu) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jorgeromero\anaconda3\lib\site-packages (from requests>=2.4->streamlit>=0.63->streamlit_option_menu) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jorgeromero\anaconda3\lib\site-packages (from requests>=2.4->streamlit>=0.63->streamlit_option_menu) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from requests>=2.4->streamlit>=0.63->streamlit_option_menu) (2.0.4)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit>=0.63->streamlit_option_menu) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from rich>=10.11.0->streamlit>=0.63->streamlit_option_menu) (2.11.2)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\jorgeromero\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit>=0.63->streamlit_option_menu) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\users\jorgeromero\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit>=0.63->streamlit_option_menu) (2022.4)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from validators>=0.2->streamlit>=0.63->streamlit_option_menu) (5.1.1)
# Installing collected packages: streamlit-option-menu
# Successfully installed streamlit-option-menu-0.3.2
# Collecting streamlit_multipage
#   Downloading streamlit_multipage-0.0.18-py3-none-any.whl (19 kB)
# Installing collected packages: streamlit-multipage
# Successfully installed streamlit-multipage-0.0.18
# Requirement already satisfied: matplotlib in c:\users\jorgeromero\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\jorgeromero\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jorgeromero\anaconda3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\jorgeromero\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\jorgeromero\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jorgeromero\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\jorgeromero\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\jorgeromero\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## Running the app
#
# Once all the requiered libraries were correctly loaded, let's proceed running the app.
#
#    1. Open a new terminal. For opening a new terminal, go the top left corner of Python console click on 'File' -> 'New'->'Terminal'
#
#    2. You will be requiered to navigate across your directories using terminal commands. A quick guide on how to navigate the directory can be found following this [link](https://riptutorial.com/terminal/example/26023/basic-navigation-commands). You will need to place you directory in the folder in which the app files are located. If you paste this folder in your hard drive :C your terminal command should look like :
#         <code> C:\KSU-WHEAT-APP> </code>
#    3. Once you succesfully reached the correct folder you will need to run the following command:
#         <code> streamlit run main.py </code>
#    4. The aforementioned command should automatically launch the app. However if it does not lauch automatically you can use any of the links provided:
#
#         <code> Local URL: http://localhost:8503<code>
#         <code> Network URL: http://129.130.90.72:8503<code>
#    5. If you are accesing the app through your cell phone or through a different IP address as the one the computer from the lab is connected you should run the 'Network URL' link. This is important, otherwise tha app will not run.

# %% [markdown]
# ## Surfing the app!
#
# ### Labels Generator App
#
#    This app was deployed with the objective of having a unique identifier for each of the samples we generate in our laboratory. Shortly, this app generates a label of the following format:
#    <center>**TRIAL-LOCATION-YEAR-TIME OF SAMPLING-PLOT NUMBER**<center>
#
#   The first step is to lauch the generator by loading the file named **LABELS_INPUT**.This file is contained in the app folder, or cna be loaded from a different directory. The uploader supports two different formats <code> .csv & .xlsx <code>
#
#    By clicking on **GENERATE LABELS** the software will automatically generate labels for the trials uploaded in the LABELS file. We are currently working on develpoment of a tool for systematically upload the information to the LABELS file. This will allow us to be consistent on the way we generate information across the following years.
#
#    Next step is to apply filters depending on the labels the user needs to print. Right after, specify the file name you want to save the labels in
#
#    By clickng on **DOWNLOAD LABELS** a pdf file will be generated containing the labels you generated.

# %% [markdown]
# ### Data Uploading App
#
#    The following app can be used for uploading data generated during data collection for **wheat yield components determination**. A QR code scanner is required for making correct use of this app. If you are having struggles in making the QR scanner work please visit this website. If by any chance the QR scanner stops working you can get a new one [here](https://www.amazon.com/dp/B0855MQ9Y6/ref=redir_mobile_desktop?_encoding=UTF8&aaxitk=b833172e9fc3f01c4b1be96d907c0a82&hsa_cr_id=8851932730701&pd_rd_plhdr=t&pd_rd_r=bc113f11-17f7-4088-8e77-5e88cfec821e&pd_rd_w=z9eUL&pd_rd_wg=LSiJ7&ref_=sbx_be_s_sparkle_lsi4d_asin_0_img).
#
#    The data will be saved on a file called data.csv

# %% [markdown]
# ## Canopy Cover Data Uploading App
#
# This app was deployed for efficient processing of canopy cover images. The input code was based on:
#
# Patrignani, A. and Ochsner, T.E., 2015. Canopeo: A powerful new tool for measuring fractional green canopy cover. Agronomy Journal, 107(6), pp.2312-2320
#
# For using the app you will need a GoPro camera which you can connect into you smartphone. You will need an android smartphone, otherwise the QR scanner would be unavailable.
#
# #### Steps:
#
#  1. Scan QR code in the plot stake
#
#  2. Load the most recent file corresponded to the last picture you have taken with the Go Pro camera.
#
#  3. Select the developmental stage of the crop at the moment you are taking the canopy picture.
#
#  4. Click on LOAD CANOPY COVER DATAPOINT. By clicking this button the app will automatically process an algorithm to estimate canopy cover and save the datapoint in the computer in which you have the app running

# %% [markdown]
# ## Seed Counter and TKW calculation App
#
# This section of the app is still immature. Please, apologies for debugs that might be present on it.
#
# Shortly, this app runs an algorithm that detects each individual wheat grain placed over a white surface. Some considerations:
#
#    1. Make sure the backgroud does not include anything more then a white colors. For achieving this you can put together mutiple white paper sheets.
#    2. The image of the grains should be taken from the top lined up as much parallel as posible with the surface in which grain are located.
#    3. **AVOID SHADINGS!** Make sure when you are taking the picture no shades are present
#    4. Once you have the picture ready you can double check the grains arrangement on your paper sheet by clicking on **Check Grains Arrangement**. An image showing the grians contours will be displayed. If it does not similar to the pattern of grain the **picture needs to be re-taken or grains need to be re-arranged**
#    5. By clicking on **LOAD TKW DATAPOINT**, it will run a chunk of code for loading TKW data into a pre-determined file.

# %% [markdown]
# # HARDWARE REQUIRED
#
# ## <center> PRINTERS <center>
#
# Device required: **Brother QL-820NWB**
#
# By seaching for "Printers & scanners" in your search box in Windows, then navigating into Printer Preferences you can set the label size you want to print.  **BIG labels default size is 2.4"(h) x 3.9"(w). SMALL labels are 1.4"(h) x 3.5"(w)**.

# %% [markdown]
# ## <center> QR CODE SCANNER <center>
#
# #### Setting the QR scanner to your smartphone or computer
#
#   The labels can be read easy and fast with a [NETUM C750 QR CODE SCANNER](https://www.netum.net/es/pages/barcode-scanner-user-manuals). By following this [link](https://cdn.shopify.com/s/files/1/2144/8019/files/NETUM_C_Series_Quick_Start_Manual.pdf?v=1644138901) you can get access to the users guide. Shorly, you can scan the 2nd available barcode on the guide to set UBS mode in your computer (make sure you plugged in the USB port). If you are working from an Android smartphone you can connect via Bluetooth by scanning the 5th barcode in the users guide.
#
#   When using the QR scanner in your Android smartphonne the keyboard language needs to be set to **ENGLISH**
