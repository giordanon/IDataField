# %%
for trial_name in trials:
    TRIAL = trial_name
    print(TRIAL)
# Out:
# go
# dp

# %%
trials = ['go', 'dp']
trials
# Out:
# ['go', 'dp']

# %%
df = df.assign(mean=df.mean(axis=1))

# %%
import pandas as pd

# %%
df = pd.read_excel("Plot Length and Plant height 2021-22. copy.xlsx")
plant_height_col = ['Plant Height (cm)', 'Plant Height (cm).1','Plant Height (cm).2' ,'Plant Height (cm).3' ,'Plant Height (cm).4','Plant Height (cm).5']
plant_height_col = {'Plant Height (cm)_1':`Plant Height (cm)_1`,
                     'Plant Height (cm)_2':`Plant Height (cm)_2`,
                     'Plant Height (cm)_3':`Plant Height (cm)_3` ,
                     'Plant Height (cm)_4':`Plant Height (cm)_4` ,
                     'Plant Height (cm)_5':`Plant Height (cm)_5`,
                     'Plant Height (cm)_6':`Plant Height (cm)_6`}
df['Plant Height (cm) Mean'] = df[plant_height_col].mean(axis=1)
df['Plant Height (cm) SD'] = df[plant_height_col].std(axis=1)
# Out:
#   File "<ipython-input-33-a33409a4308c>", line 3
#     plant_height_col = {'Plant Height (cm)_1':`Plant Height (cm)_1`,
#                                               ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#          Year Location Trial  Plot  Plot Length (m)  Plant Height (cm)  \
# 0     2021-22    HUT.E    DP   101           9.4488               53.0
# 1     2021-22    HUT.E    DP   102           9.1440               52.0
# 2     2021-22    HUT.E    DP   103           9.4488               58.0
# 3     2021-22    HUT.E    DP   104           9.4488               59.0
# 4     2021-22    HUT.E    DP   105           9.3726               50.0
# ...       ...      ...   ...   ...              ...                ...
# 5228  2021-22       AB  RAIN   409          16.1036                NaN
# 5229  2021-22       AB  RAIN   414          16.0782                NaN
# 5230  2021-22       AB  RAIN   415          15.7734                NaN
# 5231  2021-22       AB  RAIN   416          15.3162                NaN
# 5232  2021-22       AB  RAIN   417          15.5448                NaN
#
#       Plant Height (cm).1  Plant Height (cm).2  Plant Height (cm).3  \
# ...
